# %% [markdown]
# # Convolution Nural Networks

# %% [markdown]
# The Ultimate Guide to Convolutional Neural Networks: https://www.superdatascience.com/blogs/the-ultimate-guide-to-convolutional-neural-networks-cnn

# %% [markdown]
# filter or feature detector: 3x3
# ![1.png](attachment:1.png)

# %% [markdown]
# Using different filter/feature detectors we can create different feature maps to extract different features.
# Main purpose of convoluion is to find the important features and build different feature maps

# %% [markdown]
# # ReLU Layer

# %% [markdown]
# ![2.png](attachment:2.png)
# The purpose of applying the rectifier function is to increase the non-linearity in our images
# What the rectifier function does to an image is remove all the black elements from it, keeping only those carrying a positive value (the grey and white colors).

# %% [markdown]
# # Max Pooling

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# Types of Pooling:
# * Mean pooling
# * Max pooling
# * Sum pooling

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# Reduce the spatial size of the representation to reduce the amount of parameters and computation in the network.
# Prevent overfitting as well by reducing the parameters.
# As humans disregarding the unncessary information would improved the quality of the output
# 2D visualization of Convolution NN: https://www.cs.ryerson.ca/~aharley/vis/conv/flat.html

# %% [markdown]
# # Flattening

# %% [markdown]
# flatten our pooled feature map into a column like in the image below.The reason we do this is that we're going to need to insert this data into an artificial neural network later on.
# ![5.png](attachment:5.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ### How to improve the performance of the NN
#
# Adding more feature detectors
#
# Dropouts - dropping out units in a NN, this is a regularization technique for reducing overfitting, it will reduce the co-dependency among the nerons, so network would be able to genralize
#
# Confusion matrix - TP (True Positive), TN (True Negetive), FP (False positive: Type I), FN (False Negetive: Type II)
#
# Classification Accuracy = (TP+TN)/(TP+TN+FP+FN)
#
# Misclassification Rate (Error Rate) = (FP + FN)/(TP+TN+FP+FN)
#
# Precision = TP/(TP+FP) : When model predicted True class, how often it is right
#
# Recall = TP/(TP+FN) : When the class is actually true, how often did the classifier get it right
